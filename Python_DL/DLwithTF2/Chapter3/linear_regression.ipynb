# %% [markdown]
# # Simple Linear Regression

# %%
import tensorflow as tf 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 

np.random.seed(42)

area = 2.5 * np.random.randn(100) + 25
price = 25 * area + 5 + np.random.randint(20, 50, size=len(area))

# %%
data = np.array([area, price])
data = pd.DataFrame(data=data.T, columns=['area', 'price'])
data.head()
# Out:
#         area       price
# 0  26.241785  689.044635
# 1  24.654339  670.358481
# 2  26.619221  694.480534
# 3  28.807575  745.189366
# 4  24.414617  653.365414

# %%
plt.scatter(data['area'], data['price'])
plt.show()

# %%
W = sum(price * (area - np.mean(area))) / sum((area - np.mean(area)) ** 2)
b = np.mean(price) - W * np.mean(area)

print('The regression coefficients are: {} {}'.format(W, b))
# Out:
# The regression coefficients are: 25.118436284243426 36.50984088304381

# %%
# predicited values
y_pred = W * area + b

# %%
plt.plot(area, y_pred, color='red', label='Predicted Price')
plt.scatter(data['area'], data['price'], label='Training Data')
plt.xlabel('Area')
plt.ylabel('Price')
plt.legend()
plt.show()
