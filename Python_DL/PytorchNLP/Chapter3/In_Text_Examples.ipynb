# %%
import numpy as np 
import torch 
import torch.nn as nn 
import torch.nn.functional as F 

torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
np.random.seed(42)

# %matplotlib inline

# %% [markdown]
# # Example 3-1
# ## Perceptron

# %%
class Perceptron(nn.Module):
    '''
    A perceptron is one linear layer
    '''
    def __init__(self, input_dim):
        super(Perceptron, self).__init__()
        self.fc1 = nn.Linear(input_dim, 1)

    def forward(self, input):
        return nn.Sigmoid(self.fc1(input)).squeeze()

# %% [markdown]
# # Activation Functions
# ## Sigmoid Activation

# %%
import torch 
import matplotlib.pyplot as plt 

x = torch.arange(-5., 5., 0.1)
y = torch.sigmoid(x)

plt.plot(x.numpy(), y.detach().numpy())
plt.show()

# %% [markdown]
# ## Tanh Activation

# %%
y = torch.tanh(x)

plt.plot(x.numpy(), y.detach().numpy())
plt.show()

# %% [markdown]
# ## ReLU Activation

# %%
y = torch.relu(x)

plt.plot(x.numpy(), y.detach().numpy())
plt.show()

# %% [markdown]
# # Loss Functions
# ## MSE Loss

# %%
outputs = torch.randn(5, 5, requires_grad=True)
targets = torch.randn(5, 5)

mse_loss = nn.MSELoss()(outputs, targets)

print(f"mse_loss: {mse_loss} \t mse_loss_backward: {mse_loss.backward()}")
# Out:
# mse_loss: 1.400924563407898 	 mse_loss_backward: None
